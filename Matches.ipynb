# %% [markdown]
# Load CSV using pandas

# %%
import pandas as pd
df = pd.read_csv('data/matches.csv')

# %% [markdown]
#  List all the columns

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# List the first 3 data

# %%
df.head(3)
# Out:
#    id  season       city      date                team1  \
# 0   1    2017  Hyderabad  4/5/2017  Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017       Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %% [markdown]
# Print the column -> Venue and Winner

# %%
df[['city', 'winner']]
# Out:
#               city                       winner
# 0        Hyderabad          Sunrisers Hyderabad
# 1             Pune       Rising Pune Supergiant
# 2           Rajkot        Kolkata Knight Riders
# 3           Indore              Kings XI Punjab
# 4        Bangalore  Royal Challengers Bangalore
# ..             ...                          ...
# 751         Mumbai               Mumbai Indians
# 752        Chennai               Mumbai Indians
# 753  Visakhapatnam               Delhi Capitals
# 754  Visakhapatnam          Chennai Super Kings
# 755      Hyderabad               Mumbai Indians
#
# [756 rows x 2 columns]

# %% [markdown]
# Print the data that is between records 5 to 8

# %%
df[5:9]
# Out:
#    id  season       city       date                        team1  \
# 5   6    2017  Hyderabad   4/9/2017                Gujarat Lions
# 6   7    2017     Mumbai   4/9/2017        Kolkata Knight Riders
# 7   8    2017     Indore  4/10/2017  Royal Challengers Bangalore
# 8   9    2017       Pune  4/11/2017             Delhi Daredevils
#
#                     team2                  toss_winner toss_decision  result  \
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians               Mumbai Indians         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 8  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 5           0  Sunrisers Hyderabad            0               9
# 6           0       Mumbai Indians            0               4
# ...

# %% [markdown]
# Replace all column Name from Upper -> Lower

# %%
df.columns.str.upper()
# Out:
# (756, 18)

# %% [markdown]
# print data types

# %%
df.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %% [markdown]
# Add 2 new columns -> Match Start Time (7:00 PM), Dew? (False)

# %%
df['Match Start Time'] = '7:00 PM'
df['Dew?'] = False
df.dtypes
# Out:
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3             object
# Match Start Time    object
# Dew?                  bool
# dtype: object

# %% [markdown]
# Drop the columns: umpire3

# %%
df.drop(columns=['umpire3'], inplace=True)
df.columns
# Out:
# Index(['season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'Match Start Time', 'Dew?'],
#       dtype='object')

# %% [markdown]
# Rename venue -> stadium

# %%
df.rename(columns={"venue" : "stadium"}, inplace=True)
df.columns
# Out:
# Index(['season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'stadium', 'umpire1', 'umpire2',
#        'Match Start Time', 'Dew?'],
#       dtype='object')

# %% [markdown]
# Count the number of result that are not normal

# %%
df[df['result'] != 'normal']['result'].size
# Out:
# 13

# %% [markdown]
# Drop the results that are not normal

# %%
df.drop(df[df['result'] != 'normal'].index)
# Out:
#        season           city       date                        team1  \
# id
# 1        2017      Hyderabad   4/5/2017          Sunrisers Hyderabad
# 2        2017           Pune   4/6/2017               Mumbai Indians
# 3        2017         Rajkot   4/7/2017                Gujarat Lions
# 4        2017         Indore   4/8/2017       Rising Pune Supergiant
# 5        2017      Bangalore   4/8/2017  Royal Challengers Bangalore
# ...       ...            ...        ...                          ...
# 11347    2019         Mumbai   5/5/2019        Kolkata Knight Riders
# 11412    2019        Chennai   7/5/2019          Chennai Super Kings
# 11413    2019  Visakhapatnam   8/5/2019          Sunrisers Hyderabad
# 11414    2019  Visakhapatnam  10/5/2019               Delhi Capitals
# 11415    2019      Hyderabad  12/5/2019               Mumbai Indians
#
#                              team2                  toss_winner toss_decision  \
# id
# ...

# %% [markdown]
#  Add a new column: Domestic

# %%
# df['Domestic'] = True
df['Domestic'] = ~df['city'].isin(['Durban','Cape Town','Port Elizabeth','Durban','Centurion','East London','Johannesburg','Kimberley','Abu Dhabi','Sharjah'])
