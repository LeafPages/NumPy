# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
df = pd.read_csv('data/Churn1 (Comma).csv', index_col=['Stateb'])
type(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-9eabaa2d8f0d> in <module>
# ----> 1 df = pd.read_csv('data/Churn1 (Comma).csv', index_col=['Stateb'])
#       2 type(df)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df.head(1)
# Out:
#   Customer State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    A1001    KS             128        415  382-4657         no        yes
#
#    VMail Message  Day Mins  Day Calls  ...  Eve Calls  Eve Charge  Night Mins  \
# 0             25     265.1        110  ...         99       16.78       244.7
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3          2.7
#
#    CustServ Calls  Churn?
# 0               1  False.
#
# [1 rows x 22 columns]

# %%
df.tail(1)
# Out:
#          State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# Customer
# A4333       TN              74        415  400-4344         no        yes
#
#           VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# Customer                                                  ...
# A4333                25     234.4        113       39.85  ...         82
#
#           Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# Customer
# A4333           22.6       241.4           77         10.86       13.7
#
#           Intl Calls  Intl Charge  CustServ Calls  Churn?
# Customer
# A4333              4          3.7               0  False.
#
# [1 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'Int'l Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State              object
# Account Length      int64
# Area Code           int64
# Phone              object
# Int'l Plan         object
# VMail Plan         object
# VMail Message       int64
# Day Mins          float64
# Day Calls           int64
# Day Charge        float64
# Eve Mins          float64
# Eve Calls           int64
# Eve Charge        float64
# Night Mins        float64
# Night Calls         int64
# Night Charge      float64
# Intl Mins         float64
# Intl Calls          int64
# Intl Charge       float64
# CustServ Calls      int64
# Churn?             object
# dtype: object

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['State', 'Account_Length', 'Area_Code', 'Phone', 'Int'l_Plan',
#        'VMail_Plan', 'VMail_Message', 'Day_Mins', 'Day_Calls', 'Day_Charge',
#        'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins', 'Night_Calls',
#        'Night_Charge', 'Intl_Mins', 'Intl_Calls', 'Intl_Charge',
#        'CustServ_Calls', 'Churn?'],
#       dtype='object')

# %%
pd.read_csv('data/Churn2 (No Header).csv', header=None,usecols=[0,1])
# ,names=['A','B']
# Out:
#           0   1
# 0     A1001  KS
# 1     A1002  OH
# 2     A1003  NJ
# 3     A1004  OH
# 4     A1005  OK
# ...     ...  ..
# 3328  A4329  AZ
# 3329  A4330  WV
# 3330  A4331  RI
# 3331  A4332  CT
# 3332  A4333  TN
#
# [3333 rows x 2 columns]

# %%
df.shape
# Out:
# (3333, 21)

# %%
df1 = pd.read_csv('data/Churn1 (Comma).csv')

# %%
df1.head()
# Out:
#   Customer State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    A1001    KS             128        415  382-4657         no        yes
# 1    A1002    OH             107        415  371-7191         no        yes
# 2    A1003    NJ             137        415  358-1921         no         no
# 3    A1004    OH              84        408  375-9999        yes         no
# 4    A1005    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  ...  Eve Calls  Eve Charge  Night Mins  \
# 0             25     265.1        110  ...         99       16.78       244.7
# 1             26     161.6        123  ...        103       16.62       254.4
# 2              0     243.4        114  ...        110       10.30       162.6
# 3              0     299.4         71  ...         88        5.26       196.9
# 4              0     166.7        113  ...        122       12.61       186.9
#
# ...

# %%
df1.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.Account_Length
# Out:
# 0       128
# 1       107
# 2       137
# 3        84
# 4        75
#        ...
# 3328    192
# 3329     68
# 3330     28
# 3331    184
# 3332     74
# Name: Account_Length, Length: 3333, dtype: int64

# %%
df.describe(include=['int64'])
# df.dtypes
# Out:
#        Account_Length    Area_Code  VMail_Message    Day_Calls    Eve_Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   100.435644   100.114311
# std         39.822106    42.371290      13.688365    20.069084    19.922625
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000    87.000000    87.000000
# 50%        101.000000   415.000000       0.000000   101.000000   100.000000
# 75%        127.000000   510.000000      20.000000   114.000000   114.000000
# max        243.000000   510.000000      51.000000   165.000000   170.000000
#
#        Night_Calls   Intl_Calls  CustServ_Calls
# count  3333.000000  3333.000000     3333.000000
# mean    100.107711     4.479448        1.562856
# std      19.568609     2.461214        1.315491
# min      33.000000     0.000000        0.000000
# ...

# %%
type(df.State)
# Out:
# pandas.core.series.Series

# %%
df['Total_Calls'] = df['Day_Calls'] + df['Eve_Calls'] + df['Night_Calls']
df
# Out:
#      Customer State  Account_Length  Area_Code     Phone Int'l_Plan  \
# 0       A1001    KS             128        415  382-4657         no
# 1       A1002    OH             107        415  371-7191         no
# 2       A1003    NJ             137        415  358-1921         no
# 3       A1004    OH              84        408  375-9999        yes
# 4       A1005    OK              75        415  330-6626        yes
# ...       ...   ...             ...        ...       ...        ...
# 3328    A4329    AZ             192        415  414-4276         no
# 3329    A4330    WV              68        415  370-3271         no
# 3330    A4331    RI              28        510  328-8230         no
# 3331    A4332    CT             184        510  364-6381        yes
# 3332    A4333    TN              74        415  400-4344         no
#
#      VMail_Plan  VMail_Message  Day_Mins  Day_Calls  ...  Eve_Charge  \
# 0           yes             25     265.1        110  ...       16.78
# ...

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Account_Length', 'Area_Code', 'Phone',
#        'Int'l_Plan', 'VMail_Plan', 'VMail_Message', 'Day_Mins', 'Day_Calls',
#        'Day_Charge', 'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins',
#        'Night_Calls', 'Night_Charge', 'Intl_Mins', 'Intl_Calls', 'Intl_Charge',
#        'CustServ_Calls', 'Churn?', 'Total_Calls'],
#       dtype='object')

# %%
df.drop(columns=['Intl_Calls'], inplace=True)
df.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-f9e681ffad95> in <module>
# ----> 1 df.drop(columns=['Intl_Calls'], inplace=True)
#       2 df.columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop(index=[0,1])
df.shape
# Out:
# (3333, 21)

# %%
df.drop_duplicates
df.shape
# Out:
# (3333, 21)

# %%
df.sort_values(['State', 'VMail_Plan'], inplace=True)
df.head()
# Out:
#      Customer State  Account_Length  Area_Code     Phone Int'l_Plan  \
# 181     A1182    AK             126        415  372-3750         no
# 339     A1340    AK              78        408  336-5406         no
# 550     A1551    AK             111        415  364-7719         no
# 2929    A3930    AK              71        510  332-2275         no
# 1054    A2055    AK              50        408  362-8331         no
#
#      VMail_Plan  VMail_Message  Day_Mins  Day_Calls  ...  Eve_Mins  Eve_Calls  \
# 181          no              0      58.2         94  ...     138.7        118
# 339          no              0     225.1         67  ...     199.2        127
# 550          no              0     172.8         58  ...     183.1        108
# 2929         no              0     185.0         84  ...     232.5        129
# 1054         no              0     183.6        107  ...      58.6        118
#
#       Eve_Charge  Night_Mins  Night_Calls  Night_Charge  Intl_Mins  \
# ...

# %%
df.sort_index()
# Out:
#      Customer State  Account_Length  Area_Code     Phone Int'l_Plan  \
# 0       A1001    KS             128        415  382-4657         no
# 1       A1002    OH             107        415  371-7191         no
# 2       A1003    NJ             137        415  358-1921         no
# 3       A1004    OH              84        408  375-9999        yes
# 4       A1005    OK              75        415  330-6626        yes
# ...       ...   ...             ...        ...       ...        ...
# 3328    A4329    AZ             192        415  414-4276         no
# 3329    A4330    WV              68        415  370-3271         no
# 3330    A4331    RI              28        510  328-8230         no
# 3331    A4332    CT             184        510  364-6381        yes
# 3332    A4333    TN              74        415  400-4344         no
#
#      VMail_Plan  VMail_Message  Day_Mins  Day_Calls  ...  Eve_Mins  Eve_Calls  \
# ...

# %%
df.sort_values(['Area_Code','Phone'], ascending=True)
# Out:
#      Customer State  Account_Length  Area_Code     Phone Int'l_Plan  \
# 2087    A3088    NE             105        408  327-6764         no
# 2131    A3132    OH              52        408  327-9289         no
# 2762    A3763    DC              80        408  327-9957         no
# 1911    A2912    CO             118        408  328-1222         no
# 973     A1974    OH             137        408  328-2110         no
# ...       ...   ...             ...        ...       ...        ...
# 1037    A2038    RI              87        510  421-7214        yes
# 2635    A3636    NC              76        510  421-8141         no
# 2556    A3557    WA             118        510  422-2571         no
# 1258    A2259    RI             107        510  422-8268        yes
# 3026    A4027    NE              78        510  422-8333         no
#
#      VMail_Plan  VMail_Message  Day_Mins  Day_Calls  ...  Eve_Mins  Eve_Calls  \
# ...

# %%
df.VMail_Message
# Out:
# 181      0
# 339      0
# 550      0
# 2929     0
# 1054     0
#         ..
# 1422    31
# 1689    39
# 562     28
# 1847    39
# 1265    39
# Name: VMail_Message, Length: 3333, dtype: int64

# %%
df.rename(columns=["State" : "Zone"])
