# %%
import numpy as np
import pandas as pd

# %%
matches_df = pd.read_csv('data/matches.csv')

# %%
matches_df['umpire3'].value_counts().idxmax()
# Out:
# 'Nitin Menon'

# %%
matches_df  = matches_df['umpire3'].fillna(matches_df['umpire3'].value_counts().idxmax())

# %%
deliveries_df  = pd.read_csv('data/deliveries.csv')
deliveries_df.shape
# Out:
# (179078, 21)

# %%
upper_limit = deliveries_df.total_runs.std()
upper_limit
# Out:
# 1.6054216425608103

# %%
lower_limit = deliveries_df.total_runs.mean()-deliveries_df.total_runs.std()
lower_limit
# Out:
# -0.29152490482641524

# %%
deliveries_df[(deliveries_df['total_runs'] > 6)].shape
# Out:
# (118, 21)

# %%
upper_lim = deliveries_df['total_runs'].quantile(.95)
lower_lim = deliveries_df['total_runs'].quantile(.05)
print(upper_lim)
print(b)

deliveries_df['total_runs'].mean()
# Out:
# 4.0
# 0.0
# 1.313896737734395

# %%
deliveries_df[deliveries_df.batting_team.isin( deliveries_df.batting_team.value_counts().nlargest(9).index)]
# deliveries_df.batting_team.value_counts().nlargest(9)
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 6              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 7              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %%
matches_df.isna().sum()
# Out:
# 0

# %%
deliveries_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# deliveries_df['total_runs_over'] = deliveries_df.groupby(['match_id','inning',over']).total_runs.transform('sum')
# deliveries_df.head(6)
# fm = deliveries_df[deliveries_df.match_id = 1]
# deliveries_df.groupby(['match_id','over']).total_runs.sum().head()
# fm
# deliveries_df[(deliveries_df.match_id == 1) & (deliveries_df.over == 1)]
deliveries_df['total_runs_over'] = deliveries_df.groupby(['match_id','inning','over']).total_runs.transform('sum')
deliveries_df.head(15)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %%
deliveries_df['bin'] = pd.cut(deliveries_df['batsman_runs'], bins=[0,0.9,3.9,6.1], labels=["zero", "Single", "Boundaries"], include_lowest=True)

# %%
deliveries_df.bin
# Out:
# 0               zero
# 1               zero
# 2         Boundaries
# 3               zero
# 4               zero
# 5               zero
# 6               zero
# 7             Single
# 8         Boundaries
# 9               zero
# 10        Boundaries
# 11              zero
# 12              zero
# 13        Boundaries
# 14            Single
# 15              zero
# 16              zero
# 17            Single
# 18            Single
# 19            Single
# 20              zero
# 21            Single
# 22              zero
# 23            Single
# 24            Single
# 25            Single
# 26            Single
# 27            Single
# 28            Single
# 29            Single
#              ...
# 179048    Boundaries
# 179049        Single
# 179050    Boundaries
# 179051    Boundaries
# 179052    Boundaries
# 179053        Single
# 179054        Single
# 179055        Single
# 179056          zero
# 179057          zero
# 179058        Single
# 179059        Single
# ...

# %%
deliveries_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'total_runs_over', 'bin'],
#       dtype='object')

# %%
deliveries_df.dismissal_kind.unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
deliveries_df['dismissal_type'] = deliveries_df.dismissal_kind.map({'caught' : 'caught and bowled', 'bowled' : 'caught and bowled', 'retired hurt' : 'others', 'hit wicket' : 'others',  'obstructing the field' : 'others'})

# %%
deliveries_df.dismissal_type.unique()
# Out:
# array([nan, 'caught and bowled', 'others'], dtype=object)

# %%
dismissals_df = deliveries_df[deliveries_df['dismissal_kind'].notna()]
dismissals_df.dismissal_kind.value_counts()
dismissalkind_df = pd.get_dummies(dismissals_df['dismissal_kind'])
dismissalkind_df
pd.concat([dismissals_df, dismissalkind_df], axis=1)
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 116            1       1          Sunrisers Hyderabad
# 160            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 179019     11415       2          Chennai Super Kings
# 179033     11415       2          Chennai Super Kings
# 179067     11415       2          Chennai Super Kings
# 179075     11415       2          Chennai Super Kings
# 179077     11415       2          Chennai Super Kings
#
#                        bowling_team  over  ball        batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5      DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3       S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2   MC Henriques  Yuvraj Singh
# ...

# %%
 deliveries_df['score_bin'] = pd.cut(deliveries_df['batsman_runs'], bins=[0,0.9,3.9,6.1], labels=["dot", "Single", "Boundaries"], include_lowest=True)

# %%
deliveries_df.dismissal_kind.value_counts()
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %% [markdown]
# Load the dataset with date

# %%
df = pd.read_csv('data/matches.csv', parse_dates=['date'])

# %% [markdown]
# Convert to specific date format /
# pd.to_datetime(data,format=%d-%m-%y)

# %%
# pd.to_datetime
df.date.tail(20)
# Out:
# 736   2019-04-23
# 737   2019-04-24
# 738   2019-04-25
# 739   2019-04-26
# 740   2019-04-27
# 741   2019-04-28
# 742   2019-04-28
# 743   2019-04-29
# 744   2019-04-30
# 745   2019-01-05
# 746   2019-02-05
# 747   2019-03-05
# 748   2019-04-05
# 749   2019-04-05
# 750   2019-05-05
# 751   2019-05-05
# 752   2019-07-05
# 753   2019-08-05
# 754   2019-10-05
# 755   2019-12-05
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Separate the year and month and day

# %%
df.date.dt.day
# Out:
# 0      5
# 1      6
# 2      7
# 3      8
# 4      8
#       ..
# 751    5
# 752    5
# 753    5
# 754    5
# 755    5
# Name: date, Length: 756, dtype: int64

# %% [markdown]
# Print the day name

# %%
df.date.dt.day_name()
# Out:
# 0      Wednesday
# 1       Thursday
# 2         Friday
# 3       Saturday
# 4       Saturday
#          ...
# 751       Sunday
# 752       Friday
# 753       Monday
# 754     Saturday
# 755     Thursday
# Name: date, Length: 756, dtype: object

# %% [markdown]
# Print today's date

# %%
from datetime import date
date.today()
# Out:
# datetime.date(2019, 11, 16)
